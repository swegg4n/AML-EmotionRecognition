# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
import torchvision.utils as vutils
from torch.utils.data import WeightedRandomSampler, DataLoader, Dataset

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd

import seaborn as sns
from scipy import ndimage

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print('running on:', device)
# Out:
# running on: cuda:0

# %%
SOURCE_IMG_SIZE = 48
IMG_SIZE = 96

CLASSES = ['neutral', 'happy', 'surprised', 'sad', 'angry'] #, 'disgusted', 'afraid'
NUM_CLASSES = len(CLASSES)

# %% [markdown]
# ## Pre-processing

# %%
df_fer = pd.read_csv('../data/fer2013.csv').iloc[:, 1:]
df_ferplus = pd.read_csv('../data/ferplus2013.csv').iloc[:, [2, 3, 4, 5, 6]]
df = df_fer.join(df_ferplus)
# df.head(15)

df['emotion'] = df.iloc[:, 2:].idxmax(axis=1).tolist()
df = df.replace(dict(zip(pd.Series(CLASSES),pd.Series(CLASSES).index)))
# df.head(15)

print('number of images:', df.shape[0])
df = df[(df.iloc[:, 2:-1].max(axis=1) > 5)]
print('after removing images with unknown/unsure classification:', df.shape[0])
# df.head(15)

df = df.iloc[:, [0, 1, -1]]
# df.head(15)
# Out:
# number of images: 35887
# after removing images with unknown/unsure classification: 26811

# %%
# ---- Normal Dataset ----
# transform = transforms.Compose([
#     transforms.Resize((IMG_SIZE, IMG_SIZE)),
#     transforms.ToTensor()
# ])

# images_np = np.array(df['pixels'])
# label_np = np.array(df['emotion'])

# images = []
# images_raw = []
# labels = []

# for i in range(df.shape[0]):
#     b = bytes(int(p) for p in images_np[i].split())
#     img = Image.frombuffer('L', (SOURCE_IMG_SIZE, SOURCE_IMG_SIZE), b)
#     images.append(transform(img))
#     images_raw.append(img)
#     labels.append(label_np[i])

# ---- Large Dataset ----
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.RandomRotation(30),
])

images_np = np.array(df['pixels'])
label_np = np.array(df['emotion'])

images = []
images_raw = []
labels = []

for i in range(df.shape[0]):
    for j in range(4):
        b = bytes(int(p) for p in images_np[i].split())
        img = Image.frombuffer('L', (SOURCE_IMG_SIZE, SOURCE_IMG_SIZE), b)
        transformed_img = transform(img)
        transformed_img[transformed_img == 0] = 0.5
        images.append(transformed_img)

        images_raw.append(img)
        labels.append(label_np[i])

# %% [markdown]
# ## Filtering

# %%
kirsch_compass_masks = [
    np.array([[-3,-3,5],[-3,0,5],[-3,-3,5]]),   # north
    np.array([[-3,-3,-3],[-3,0,5],[-3,5,5]]),   # north-east
    np.array([[-3,-3,-3],[-3,0,-3],[5,5,5]]),   # east
    np.array([[-3,-3,-3],[5,0,-3],[5,5,-3]]),   # south-east
    # np.array([[5,-3,-3],[5,0,-3],[5,-3,-3]]),   # south
    # np.array([[5,5,-3],[5,0,-3],[-3,-3,-3]]),   # south-west 
    # np.array([[5,5,5],[-3,0,-3],[-3,-3,-3]]),   # west
    # np.array([[-3,5,5],[-3,0,5],[-3,-3,-3]]),   # north-west
]

# %%
images_filtered = []

transform = transforms.Compose([
    transforms.ToTensor()
])

for i in range(len(images)):
    img = images[i].squeeze(0)

    filtered = np.zeros_like(img)
    for cm in kirsch_compass_masks:
        k = ndimage.convolve(img, cm, mode='nearest', cval=0.0)
        filtered = np.add(filtered, k)

    filtered = transform(filtered)
    images_filtered.append(filtered)

# %%
img = images_filtered[random.randint(0, len(images_filtered)-1)]

plt.figure(figsize=(5,5))
plt.title('kirsch')
plt.axis('off')
plt.imshow(img.permute(1,2,0), cmap='gray')

# %%
label_counts = [0]*NUM_CLASSES

for i in range(len(labels)):
    label_counts[labels[i]] += 1

print('\033[4m{: <15} {: >10}\033[0m'.format('class', '#images'))
for i in range(NUM_CLASSES):
    print('{: <15} {: >10}'.format(CLASSES[i], label_counts[i]))
# Out:
# class              #images
# neutral               9494
# happy                 8802
# surprised             3461
# sad                   2958
# angry                 2096

# %%
train_split_pct = 0.8
train_len = int(len(labels) * train_split_pct)

train_images = images_filtered[:train_len]
train_labels = labels[:train_len]
test_images = images_filtered[train_len:]
test_labels = labels[train_len:]

print(f'train length: {len(train_labels)} ({len(train_labels)*100/len(labels):.1f}%)')
print(f'test length: {len(test_labels)} ({len(test_labels)*100/len(labels):.1f}%)')
# Out:
# train length: 21448 (80.0%)
# test length: 5363 (20.0%)

# %%
BATCH_SIZE = 32


class CustomDataset(Dataset):
    
    def __init__(self, images, labels):      
        self.images = images
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.images[idx], self.labels[idx]


train_dataset = CustomDataset(train_images, train_labels)
test_dataset = CustomDataset(test_images, test_labels)


def get_loader(dataset):
    print('get_loader():')

    label_counts = [0]*NUM_CLASSES
    for i in range(len(dataset.labels)):
        label_counts[dataset.labels[i]] += 1

    class_weights = pow(np.array(label_counts) / sum(label_counts), -1)
    print('  class weights:', class_weights.round(3), '\n')

    sample_weights = [0]*len(dataset)
    for idx, (image, label) in enumerate(dataset):
        sample_weights[idx] = class_weights[label]

    sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)
    return DataLoader(dataset, BATCH_SIZE, sampler=sampler, shuffle=False)


train_loader = get_loader(train_dataset)
test_loader = get_loader(test_dataset)
# Out:
# get_loader():
#   class weights: [ 2.848  3.015  7.771  8.963 12.991]
#
# get_loader():
#   class weights: [ 2.732  3.175  7.65   9.492 12.052]

# %% [markdown]
# -----
# # VGG (Visual Geometry Group) Model

# %%
import torch.nn.init as init

import time

from torchvision.utils import _log_api_usage_once

# Batch size during training, remember to change the global one as well
batch_size = BATCH_SIZE

# Number of training epochs
num_epochs = 75

# Learning rate for optimizers
lr = 0.0001

# %%
# Function for displaying predictions for a few images, in this case 6.
#print(test_set[0])

class_names = CLASSES
print(class_names)

def visualize_expression_model(model, num_images=4):
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                plt.imshow(inputs.cpu().data[j].permute(1, 2, 0), cmap="gray")

                if images_so_far == num_images:
                    return
# Out:
# ['neutral', 'happy', 'surprised', 'sad', 'angry']

# %%
def train_expression_model(model, data, criterion, optimizer):
    since = time.time()
    best_acc = 0.0
    model.train()   # Set model to train mode
    running_loss = 0.0
    running_corrects = 0
    
    for inputs, labels in data:
        inputs = inputs.to(device)
        labels = labels.to(device)
    
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)
        
        # zero the parameter gradients, and use backpropagatation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)
        
    epoch_loss = running_loss / len(train_dataset)
    epoch_acc = running_corrects.double() / len(train_dataset)

    print('train Loss: {:.4f} Acc: {:.4f}'.format(epoch_loss, epoch_acc))

# %%
def test_expression_model(model, data, criterion):
    since = time.time()
    best_acc = 0.0
    model.eval()   # Set model to evaluate mode
    running_loss = 0.0
    running_corrects = 0
    
    for inputs, labels in data:
        inputs = inputs.to(device)
        labels = labels.to(device)
    
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)
        
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)
        
    epoch_loss = running_loss / len(test_dataset)
    epoch_acc = running_corrects.double() / len(test_dataset)

    print('test Loss: {:.4f} Acc: {:.4f}'.format(
        epoch_loss, epoch_acc))

# %%
class Fire(nn.Module):
    def __init__(self, inplanes: int, squeeze_planes: int, expand1x1_planes: int, expand3x3_planes: int) -> None:
        super().__init__()
        self.inplanes = inplanes
        self.squeeze = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1)
        self.squeeze_activation = nn.ReLU(inplace=True)
        self.expand1x1 = nn.Conv2d(squeeze_planes, expand1x1_planes, kernel_size=1)
        self.expand1x1_activation = nn.ReLU(inplace=True)
        self.expand3x3 = nn.Conv2d(squeeze_planes, expand3x3_planes, kernel_size=3, padding=1)
        self.expand3x3_activation = nn.ReLU(inplace=True)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.squeeze_activation(self.squeeze(x))
        return torch.cat(
            [self.expand1x1_activation(self.expand1x1(x)), self.expand3x3_activation(self.expand3x3(x))], 1
        )


class Facial_Expression_Network_VGG(nn.Module):
    def __init__(self, version: str = "1_0", num_classes: int = NUM_CLASSES, dropout: float = 0.5) -> None:
        super().__init__()
        _log_api_usage_once(self)
        self.num_classes = num_classes
        if version == "1_0": # train 88, test 76    (%), LR 0.0001
            self.features = nn.Sequential(
                nn.Conv2d(1, 96, kernel_size=3, stride=1), # Changed from 3 channels to 1
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(96, 16, 64, 64),
                Fire(128, 16, 64, 64),
                Fire(128, 32, 128, 128),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(256, 32, 128, 128),
                Fire(256, 48, 192, 192),
                Fire(384, 48, 192, 192),
                Fire(384, 64, 256, 256),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(512, 64, 256, 256),
            )
        elif version == "1_1": # train 96, test 75  (%), 14 min, LR 0.0005
            self.features = nn.Sequential(
                nn.Conv2d(1, 64, kernel_size=3, stride=2), # Changed from 3 channels to 1
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(64, 16, 64, 64),
                Fire(128, 16, 64, 64),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(128, 32, 128, 128),
                Fire(256, 32, 128, 128),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(256, 48, 192, 192),
                Fire(384, 48, 192, 192),
                Fire(384, 64, 256, 256),
                Fire(512, 64, 256, 256),
            )
        else:
            # FIXME: Is this needed? SqueezeNet should only be called from the
            # FIXME: squeezenet1_x() functions
            # FIXME: This checking is not done for the other models
            raise ValueError(f"Unsupported SqueezeNet version {version}: 1_0 or 1_1 expected")

        # Final convolution is initialized differently from the rest
        final_conv = nn.Conv2d(512, self.num_classes, kernel_size=1)
        self.classifier = nn.Sequential(
            nn.Dropout(p=dropout), final_conv, 
            nn.ReLU(inplace=True), 
            nn.AdaptiveAvgPool2d((1, 1))
        )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                if m is final_conv:
                    init.normal_(m.weight, mean=0.0, std=0.01)
                else:
                    init.kaiming_uniform_(m.weight)
                if m.bias is not None:
                    init.constant_(m.bias, 0)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = self.classifier(x)
        return torch.flatten(x, 1)



# def _squeezenet(version: str, pretrained: bool, progress: bool, **kwargs: Any) -> Facial_Expression_Network:
#     model = Facial_Expression_Network(version, **kwargs)
#     if pretrained:
#         arch = "squeezenet" + version
#         state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
#         model.load_state_dict(state_dict)
#     return model

# %%
expression_model = Facial_Expression_Network_VGG().to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(expression_model.parameters(), lr=lr, momentum = 0.9)
#optimizer = torch.optim.Adam(expression_model.parameters(), lr=lr)

# Decay LR by a factor of 0.1 every 1 epochs
scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.0001)

# %%
for epoch in range(1, (num_epochs+1)):
    print('Epoch {}/{}'.format(epoch, num_epochs))
    print()
    train_expression_model(expression_model, train_loader, loss_fn, optimizer)
    test_expression_model(expression_model, test_loader, loss_fn)
    scheduler.step

# Normal dataset:
#   Train: Loss = , Acc = 
#   Test: Loss = , Acc = 
#   Time = 
#   Epoks = 

# Large dataset (x4): 
#   Train: Loss = , Acc =
#   Test: Loss = , Acc = 
#   Time = 
#   Epoks =
# Out:
# Epoch 1/75
# c:\Users\Ludvi\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# train Loss: 0.0503 Acc: 0.2045
# test Loss: 0.0504 Acc: 0.1999
# Epoch 2/75
#
# train Loss: 0.0503 Acc: 0.2086
# test Loss: 0.0504 Acc: 0.2088
# Epoch 3/75
#
# train Loss: 0.0503 Acc: 0.2127
# test Loss: 0.0504 Acc: 0.2034
# Epoch 4/75
#
# train Loss: 0.0502 Acc: 0.2140
# test Loss: 0.0502 Acc: 0.1952
# Epoch 5/75
#
# train Loss: 0.0500 Acc: 0.2413
# test Loss: 0.0497 Acc: 0.2849
# Epoch 6/75
#
# train Loss: 0.0490 Acc: 0.2752
# test Loss: 0.0487 Acc: 0.2942
# Epoch 7/75
#
# train Loss: 0.0476 Acc: 0.3046
# test Loss: 0.0457 Acc: 0.3666
# Epoch 8/75
#
# train Loss: 0.0455 Acc: 0.3460
# test Loss: 0.0440 Acc: 0.3901
# Epoch 9/75
#
# train Loss: 0.0443 Acc: 0.3714
# test Loss: 0.0444 Acc: 0.3726
# Epoch 10/75
#
# train Loss: 0.0432 Acc: 0.3930
# test Loss: 0.0413 Acc: 0.4496
# Epoch 11/75
#
# train Loss: 0.0420 Acc: 0.4222
# test Loss: 0.0403 Acc: 0.4589
# Epoch 12/75
#
# train Loss: 0.0403 Acc: 0.4517
# test Loss: 0.0396 Acc: 0.4647
# Epoch 13/75
#
# train Loss: 0.0393 Acc: 0.4753
# test Loss: 0.0377 Acc: 0.4919
# Epoch 14/75
#
# train Loss: 0.0379 Acc: 0.4984
# test Loss: 0.0367 Acc: 0.5355
# Epoch 15/75
#
# train Loss: 0.0371 Acc: 0.5105
# test Loss: 0.0368 Acc: 0.5230
# Epoch 16/75
#
# train Loss: 0.0361 Acc: 0.5341
# test Loss: 0.0355 Acc: 0.5381
# Epoch 17/75
#
# train Loss: 0.0347 Acc: 0.5491
# test Loss: 0.0366 Acc: 0.5268
# Epoch 18/75
#
# train Loss: 0.0337 Acc: 0.5726
# test Loss: 0.0364 Acc: 0.5230
# Epoch 19/75
#
# train Loss: 0.0333 Acc: 0.5765
# test Loss: 0.0320 Acc: 0.6140
# Epoch 20/75
#
# train Loss: 0.0315 Acc: 0.6035
# test Loss: 0.0306 Acc: 0.6327
# Epoch 21/75
#
# train Loss: 0.0314 Acc: 0.6081
# test Loss: 0.0354 Acc: 0.5448
# Epoch 22/75
#
# train Loss: 0.0303 Acc: 0.6268
# test Loss: 0.0294 Acc: 0.6472
# Epoch 23/75
#
# train Loss: 0.0296 Acc: 0.6320
# test Loss: 0.0297 Acc: 0.6496
# Epoch 24/75
#
# train Loss: 0.0287 Acc: 0.6448
# test Loss: 0.0308 Acc: 0.6054
# Epoch 25/75
#
# train Loss: 0.0288 Acc: 0.6452
# test Loss: 0.0274 Acc: 0.6677
# Epoch 26/75
#
# train Loss: 0.0279 Acc: 0.6552
# test Loss: 0.0280 Acc: 0.6565
# Epoch 27/75
#
# train Loss: 0.0272 Acc: 0.6726
# test Loss: 0.0305 Acc: 0.6276
# Epoch 28/75
#
# train Loss: 0.0260 Acc: 0.6829
# test Loss: 0.0268 Acc: 0.6720
# Epoch 29/75
#
# train Loss: 0.0255 Acc: 0.6890
# test Loss: 0.0261 Acc: 0.6841
# Epoch 30/75
#
# train Loss: 0.0256 Acc: 0.6928
# test Loss: 0.0263 Acc: 0.6770
# Epoch 31/75
#
# train Loss: 0.0248 Acc: 0.7030
# test Loss: 0.0278 Acc: 0.6687
# Epoch 32/75
#
# train Loss: 0.0245 Acc: 0.7014
# test Loss: 0.0258 Acc: 0.6894
# Epoch 33/75
#
# train Loss: 0.0237 Acc: 0.7107
# test Loss: 0.0257 Acc: 0.6957
# Epoch 34/75
#
# train Loss: 0.0239 Acc: 0.7109
# test Loss: 0.0294 Acc: 0.6534
# Epoch 35/75
#
# train Loss: 0.0228 Acc: 0.7265
# test Loss: 0.0265 Acc: 0.6729
# Epoch 36/75
#
# train Loss: 0.0226 Acc: 0.7288
# test Loss: 0.0237 Acc: 0.7242
# Epoch 37/75
#
# train Loss: 0.0221 Acc: 0.7366
# test Loss: 0.0264 Acc: 0.6800
# Epoch 38/75
#
# train Loss: 0.0219 Acc: 0.7376
# test Loss: 0.0242 Acc: 0.7123
# Epoch 39/75
#
# train Loss: 0.0217 Acc: 0.7391
# test Loss: 0.0241 Acc: 0.7168
# Epoch 40/75
#
# train Loss: 0.0206 Acc: 0.7556
# test Loss: 0.0239 Acc: 0.7237
# Epoch 41/75
#
# train Loss: 0.0200 Acc: 0.7596
# test Loss: 0.0253 Acc: 0.6981
# Epoch 42/75
#
# train Loss: 0.0203 Acc: 0.7555
# test Loss: 0.0253 Acc: 0.7050
# Epoch 43/75
#
# train Loss: 0.0200 Acc: 0.7615
# test Loss: 0.0270 Acc: 0.6800
# Epoch 44/75
#
# train Loss: 0.0198 Acc: 0.7612
# test Loss: 0.0232 Acc: 0.7350
# Epoch 45/75
#
# train Loss: 0.0192 Acc: 0.7712
# test Loss: 0.0223 Acc: 0.7404
# Epoch 46/75
#
# train Loss: 0.0191 Acc: 0.7719
# test Loss: 0.0231 Acc: 0.7291
# Epoch 47/75
#
# train Loss: 0.0183 Acc: 0.7828
# test Loss: 0.0281 Acc: 0.6880
# Epoch 48/75
#
# train Loss: 0.0182 Acc: 0.7868
# test Loss: 0.0218 Acc: 0.7404
# Epoch 49/75
#
# train Loss: 0.0176 Acc: 0.7887
# test Loss: 0.0256 Acc: 0.7184
# Epoch 50/75
#
# train Loss: 0.0174 Acc: 0.7944
# test Loss: 0.0262 Acc: 0.6964
# Epoch 51/75
#
# train Loss: 0.0171 Acc: 0.7964
# test Loss: 0.0222 Acc: 0.7531
# Epoch 52/75
#
# train Loss: 0.0170 Acc: 0.7979
# test Loss: 0.0233 Acc: 0.7294
# Epoch 53/75
#
# train Loss: 0.0162 Acc: 0.8102
# test Loss: 0.0211 Acc: 0.7509
# Epoch 54/75
#
# train Loss: 0.0161 Acc: 0.8088
# test Loss: 0.0219 Acc: 0.7496
# Epoch 55/75
#
# train Loss: 0.0159 Acc: 0.8074
# test Loss: 0.0235 Acc: 0.7365
# Epoch 56/75
#
# train Loss: 0.0154 Acc: 0.8157
# test Loss: 0.0242 Acc: 0.7434
# Epoch 57/75
#
# train Loss: 0.0149 Acc: 0.8221
# test Loss: 0.0213 Acc: 0.7652
# Epoch 58/75
#
# train Loss: 0.0146 Acc: 0.8264
# test Loss: 0.0215 Acc: 0.7529
# Epoch 59/75
#
# train Loss: 0.0146 Acc: 0.8261
# test Loss: 0.0235 Acc: 0.7429
# Epoch 60/75
#
# train Loss: 0.0148 Acc: 0.8249
# test Loss: 0.0240 Acc: 0.7419
# Epoch 61/75
#
# train Loss: 0.0136 Acc: 0.8398
# test Loss: 0.0265 Acc: 0.7337
# Epoch 62/75
#
# train Loss: 0.0140 Acc: 0.8347
# test Loss: 0.0293 Acc: 0.7218
# Epoch 63/75
#
# train Loss: 0.0135 Acc: 0.8420
# test Loss: 0.0208 Acc: 0.7729
# Epoch 64/75
#
# train Loss: 0.0133 Acc: 0.8434
# test Loss: 0.0252 Acc: 0.7330
# Epoch 65/75
#
# train Loss: 0.0128 Acc: 0.8483
# test Loss: 0.0237 Acc: 0.7412
# Epoch 66/75
#
# train Loss: 0.0126 Acc: 0.8555
# test Loss: 0.0247 Acc: 0.7453
# Epoch 67/75
#
# train Loss: 0.0128 Acc: 0.8501
# test Loss: 0.0243 Acc: 0.7447
# Epoch 68/75
#
# train Loss: 0.0121 Acc: 0.8592
# test Loss: 0.0247 Acc: 0.7555
# Epoch 69/75
#
# train Loss: 0.0118 Acc: 0.8618
# test Loss: 0.0246 Acc: 0.7496
# Epoch 70/75
#
# train Loss: 0.0114 Acc: 0.8669
# test Loss: 0.0264 Acc: 0.7399
# Epoch 71/75
#
# train Loss: 0.0115 Acc: 0.8625
# test Loss: 0.0308 Acc: 0.7214
# Epoch 72/75
#
# train Loss: 0.0112 Acc: 0.8681
# test Loss: 0.0225 Acc: 0.7634
# Epoch 73/75
#
# train Loss: 0.0108 Acc: 0.8722
# test Loss: 0.0255 Acc: 0.7490
# Epoch 74/75
#
# train Loss: 0.0106 Acc: 0.8774
# test Loss: 0.0232 Acc: 0.7679
# Epoch 75/75
#
# train Loss: 0.0105 Acc: 0.8758
# test Loss: 0.0264 Acc: 0.7585

# %% [markdown]
# ##### End of VGG model
# -----

# %%
samples_train = [0]*NUM_CLASSES
samples_test = [0]*NUM_CLASSES

for idx, (images_filtered, labels) in enumerate(train_loader):
    for i in range(len(images_filtered)):
        samples_train[labels[i].item()] += 1

for idx, (images_filtered, labels) in enumerate(test_loader):
    for i in range(len(images_filtered)):
        samples_test[labels[i].item()] += 1


print('\033[4m{: <15} {: >15} {: >20}\033[0m'.format('class', '#samples (train)', '#samples (test)'))
for i in range(NUM_CLASSES):
    print('{: <15} {: >15} {: >20}'.format(CLASSES[i], samples_train[i], samples_test[i]))
# Out:
# class           #samples (train)      #samples (test)
# neutral                    4322                 1047
# happy                      4245                 1057
# surprised                  4336                 1096
# sad                        4238                 1125
# angry                      4307                 1038

# %%
def imshow(dataset, title='', num_images=(3,6), rand=True):

    plt.figure(figsize=(num_images[1]*1.5, num_images[0]*2)); 
    plt.suptitle(title, fontsize=16)

    for i in range(num_images[0]):
        for j in range(num_images[1]):
            
            c = num_images[1]*i+(j+1)

            if not rand:
                idx = c
            else:
                idx = random.randint(0, len(dataset)-1)

            plt.subplot(num_images[0], num_images[1], c); plt.axis('off'); plt.title(CLASSES[dataset[idx][1]])
            plt.imshow(dataset[idx][0].permute(1,2,0), cmap='gray')

    plt.tight_layout(); plt.show()


imshow(train_dataset, 'Example images from the train dataset')
